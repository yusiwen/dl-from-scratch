# %% [markdown]
# # PCA
#
# SVD-based dimensionality reduction, MNIST 2D visualisation.

# %% [markdown]
# ## 背景
#
# SVD-based dimensionality reduction, MNIST 2D visualisation. 本 notebook 演示 PCA 的完整实现，模型代码见 `basics/pca.py`。

# %% [markdown]
# ## 数学原理
#
# **中心化：** $\tilde{X} = X - \bar{x}$
#
# **SVD：** $\tilde{X} = U \Sigma V^T$
#
# **投影到前 k 个主成分：** $X_{\text{proj}} = \tilde{X} \cdot V_{:,:k}$

# %%
from basics.pca import demo

# %%
demo()

# %% [markdown]
# ## 思考题
#
# 1. PCA 的第一主成分捕获了什么？（在 MNIST 上观察 ASCII 图）
# 2. 为什么用 SVD 而不是直接做协方差矩阵的特征分解？
# 3. 保留多少主成分能保留 90% 的方差？
