# %% [markdown]
# # Logistic Regression
#
# Single Linear layer + Softmax for MNIST digit classification (92.3%).

# %% [markdown]
# ## 背景
#
# Single Linear layer + Softmax for MNIST digit classification (92.3%). 本 notebook 演示 Logistic Regression 的完整实现，模型代码见 `basics/logistic_regression.py`。

# %% [markdown]
# ## 数学原理
#
# $$P(y=c \mid x) = \frac{e^{w_c \cdot x + b_c}}{\sum_{j=1}^{10} e^{w_j \cdot x + b_j}}$$
#
# $$\mathcal{L} = -\frac{1}{N} \sum_{i=1}^N \log P(y_i \mid x_i)$$

# %%
from basics.logistic_regression import train

# %%
train()

# %% [markdown]
# ## 思考题
#
# 1. Logistic Regression 和 Linear Regression 的区别是什么？（输出 vs 损失函数）
# 2. 为什么用 Softmax + CrossEntropy 而不是 MSE 做分类？
# 3. 把学习率从 0.1 改到 0.01，准确率会怎么变？试试。
