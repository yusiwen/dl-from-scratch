# %% [markdown]
# # Linear Regression
#
# Normal Equation + Gradient Descent on California Housing (R²=0.583).

# %% [markdown]
# ## 背景
#
# Normal Equation + Gradient Descent on California Housing (R²=0.583). 本 notebook 演示 Linear Regression 的完整实现，模型代码见 `basics/linear_regression.py`。

# %% [markdown]
# ## 数学原理
#
# $$\theta = (X^T X)^{-1} X^T y \quad \text{(Normal Equation)}$$
#
# $$\theta \leftarrow \theta - \alpha \cdot \frac{2}{m} X^T (X\theta - y) \quad \text{(Gradient Descent)}$$

# %%
from basics.linear_regression import train

# %%
train()

# %% [markdown]
# ## 思考题
#
# 1. Normal Equation 和 Gradient Descent 的优缺点？
# 2. 特征标准化为什么对 GD 重要而对 Normal Equation 不重要？
# 3. 把学习率从 0.1 改到 1.0，GD 还会收敛吗？
