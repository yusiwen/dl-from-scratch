# %% [markdown]
# # Decision Tree
#
# ID3/CART on Iris dataset (93.3%, ASCII tree).

# %% [markdown]
# ## 背景
#
# ID3/CART on Iris dataset (93.3%, ASCII tree). 本 notebook 演示 Decision Tree 的完整实现，模型代码见 `basics/decision_tree.py`。

# %% [markdown]
# ## 数学原理
#
# **熵（impurity 度量）：**
#
# $$H(S) = -\sum p_i \log_2 p_i$$
#
# **信息增益：**
#
# $$IG = H(S) - \sum \frac{|S_v|}{|S|} H(S_v)$$

# %%
from basics.decision_tree import demo

# %%
demo()

# %% [markdown]
# ## 思考题
#
# 1. 决策树在 Iris 上只用了哪两个特征？为什么？（提示：print_tree 观察）
# 2. max_depth 太小会欠拟合，太大会过拟合，怎么选？
# 3. 信息增益和基尼系数（Gini impurity）有什么区别？
