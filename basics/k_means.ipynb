# %% [markdown]
# # K-Means
#
# Unsupervised clustering on MNIST, 57.8% cluster purity.

# %% [markdown]
# ## 背景
#
# Unsupervised clustering on MNIST, 57.8% cluster purity. 本 notebook 演示 K-Means 的完整实现，模型代码见 `basics/k_means.py`。

# %% [markdown]
# ## 数学原理
#
# **E-step（分配）：**
#
# $$c_i = \arg\min_k \|x_i - \mu_k\|^2$$
#
# **M-step（更新）：**
#
# $$\mu_k = \frac{1}{|C_k|} \sum_{i \in C_k} x_i$$

# %%
from basics.k_means import train

# %%
train()

# %% [markdown]
# ## 思考题
#
# 1. K-Means 一定能收敛吗？收敛到全局最优吗？
# 2. k 值怎么选？（提示：肘部法则）
# 3. 为什么 K-Means 对初始中心点敏感？K-Means++ 怎么改进？
