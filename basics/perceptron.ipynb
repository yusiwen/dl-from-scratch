# %% [markdown]
# # Perceptron
#
# Single neuron with step activation (Rosenblatt 1958).

# %% [markdown]
# ## 背景
#
# Single neuron with step activation (Rosenblatt 1958). 本 notebook 演示 Perceptron 的完整实现，模型代码见 `basics/perceptron.py`。

# %% [markdown]
# ## 数学原理
#
# $$y = \text{sign}(w \cdot x + b)$$
#
# **更新规则（误分类时）：**
#
# $$w \leftarrow w + \eta \cdot y \cdot x$$
#
# $$b \leftarrow b + \eta \cdot y$$

# %%
from basics.perceptron import demo

# %%
demo()

# %% [markdown]
# ## 思考题
#
# 1. Perceptron 为什么只能解决线性可分问题？
# 2. Perceptron 和 Logistic Regression 的核心区别是什么？
# 3. Perceptron Convergence Theorem 保证什么？
